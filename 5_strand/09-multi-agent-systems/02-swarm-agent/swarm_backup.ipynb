# %% [markdown]
# # Creating Swarm of agents using Strands Agents

# %% [markdown]
# ## Understanding Swarm Multi-Agent Systems
#
# A Swarm is a collaborative agent orchestration system where multiple agents work together as a team to solve complex tasks. Unlike traditional sequential or hierarchical multi-agent systems, a Swarm enables autonomous coordination between agents with shared context and working memory.
#
# * **Self-organizing agent teams** with shared working memory
# * **Tool-based coordination** between agents
# * **Autonomous agent collaboration** without central control
# * **Dynamic task distribution** based on agent capabilities
# * **Collective intelligence** through shared context
# * **Multi-modal input support** for handling text, images, and other content types
#
# ## How Swarms Work
#
# Swarms operate on the principle of emergent intelligence - the idea that a group of specialized agents working together can solve problems more effectively than a single agent. Each agent in a Swarm:
#
# 1. Has access to the full task context
# 2. Can see the history of which agents have worked on the task
# 3. Can access shared knowledge contributed by other agents
# 4. Can decide when to hand off to another agent with different expertise

# %% [markdown]
# ## 1. Quick Start with Swarm tool

# %% [markdown]
# The Strands Agents SDK provides a built-in swarm tool that simplifies the implementation of multi-agent systems, offering a quick start for users. This tool implements a flexible swarm intelligence system with autonomous coordination between specialized agents.
#
# In this example:
# 1. The agent uses the swarm tool to dynamically create a team of specialized agents. These might include a researcher, an analyst, and a technical writer
# 2. Next the agent executes the swarm
# 3. The swarm agents collaborate autonomously, handing off to each other as needed
# 4. The agent analyzes the swarm results and provides a comprehensive response to the user

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: strands-agents in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from -r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: strands-agents-tools in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from -r requirements.txt (line 2)) (0.2.3)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents->-r requirements.txt (line 1)) (1.40.4)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents->-r requirements.txt (line 1)) (1.40.4)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents->-r requirements.txt (line 1)) (1.12.3)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents->-r requirements.txt (line 1)) (1.36.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents->-r requirements.txt (line 1)) (0.57b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents->-r requirements.txt (line 1)) (1.36.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents->-r requirements.txt (line 1)) (2.11.7)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents->-r requirements.txt (line 1)) (4.14.1)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.13.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: anyio>=4.5 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: httpx>=0.27 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.47.1)
# Requirement already satisfied: uvicorn>=0.23.1 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.35.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.57b0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.57b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from opentelemetry-instrumentation==0.57b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.57b0)
# Requirement already satisfied: packaging>=18.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from opentelemetry-instrumentation==0.57b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.51)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: readabilipy<1.0.0,>=0.2.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.0.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.23.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: tzdata in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: requests>=0.14.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.7)
# Requirement already satisfied: wcwidth in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: html5lib in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (1.1)
# Requirement already satisfied: lxml in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (6.0.0)
# Requirement already satisfied: regex in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (2025.7.34)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.36.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: certifi in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx>=0.27->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx>=0.27->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpcore==1.*->httpx>=0.27->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.26.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=0.14.0->aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: click>=7.0 in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from uvicorn>=0.23.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (8.2.1)
# Requirement already satisfied: colorama in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from click>=7.0->uvicorn>=0.23.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\mnede\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from html5lib->readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (0.5.1)

# %%
from strands import Agent
from strands_tools import swarm
from strands.models.bedrock import BedrockModel

# %% [markdown]
# ## 1.1 Swarm as a Tool

# %%
# Agent initialization
agent = Agent(model="apac.anthropic.claude-3-7-sonnet-20250219-v1:0",tools=[swarm])

# Invocation through natural language
result = str(agent(
    "Use a swarm of 4 agents to analyze the current market trend for generative ai based agents."
))
# Out:
# I'll create a swarm of 4 specialized agents to analyze the current market trend for generative AI-based agents. Each agent will focus on a different aspect of the market to provide a comprehensive analysis.
# Tool #1: swarm
# node=<market_analyst> | node execution failed
# Traceback (most recent call last):
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\multiagent\swarm.py", line 590, in _execute_node
#     result = await node.executor.invoke_async(node_input)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 435, in invoke_async
#     async for event in events:
#         _ = event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 577, in stream_async
#     async for event in events:
#     ...<2 lines>...
#             yield event["callback"]
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 614, in _run_loop
#     async for event in events:
#     ...<13 lines>...
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 653, in _execute_event_loop_cycle
#     async for event in events:
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 194, in event_loop_cycle
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 136, in event_loop_cycle
#     async for event in stream_messages(agent.model, agent.system_prompt, agent.messages, tool_specs):
#     ...<6 lines>...
#             }
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 319, in stream_messages
#     async for event in process_stream(chunks):
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 276, in process_stream
#     async for chunk in chunks:
#     ...<15 lines>...
#             handle_redact_content(chunk["redactContent"], state)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 397, in stream
#     await task
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py", line 171, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 494, in _stream
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 431, in _stream
#     response = self.client.converse_stream(**request)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# └ Bedrock region: ap-southeast-2
# └ Model id: us.anthropic.claude-sonnet-4-20250514-v1:0
# node=<market_analyst> | node execution failed
# Traceback (most recent call last):
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\multiagent\swarm.py", line 528, in _execute_swarm
#     await asyncio.wait_for(
#     ...<2 lines>...
#     )
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\asyncio\tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\multiagent\swarm.py", line 590, in _execute_node
#     result = await node.executor.invoke_async(node_input)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 435, in invoke_async
#     async for event in events:
#         _ = event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 577, in stream_async
#     async for event in events:
#     ...<2 lines>...
#             yield event["callback"]
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 614, in _run_loop
#     async for event in events:
#     ...<13 lines>...
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 653, in _execute_event_loop_cycle
#     async for event in events:
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 194, in event_loop_cycle
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 136, in event_loop_cycle
#     async for event in stream_messages(agent.model, agent.system_prompt, agent.messages, tool_specs):
#     ...<6 lines>...
#             }
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 319, in stream_messages
#     async for event in process_stream(chunks):
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 276, in process_stream
#     async for chunk in chunks:
#     ...<15 lines>...
#             handle_redact_content(chunk["redactContent"], state)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 397, in stream
#     await task
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py", line 171, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 494, in _stream
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 431, in _stream
#     response = self.client.converse_stream(**request)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# └ Bedrock region: ap-southeast-2
# └ Model id: us.anthropic.claude-sonnet-4-20250514-v1:0
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# I apologize for the error with the swarm execution. Let me try again with a more focused approach:
# Tool #2: swarm
# node=<market_analyst> | node execution failed
# Traceback (most recent call last):
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\multiagent\swarm.py", line 590, in _execute_node
#     result = await node.executor.invoke_async(node_input)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 435, in invoke_async
#     async for event in events:
#         _ = event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 577, in stream_async
#     async for event in events:
#     ...<2 lines>...
#             yield event["callback"]
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 614, in _run_loop
#     async for event in events:
#     ...<13 lines>...
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 653, in _execute_event_loop_cycle
#     async for event in events:
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 194, in event_loop_cycle
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 136, in event_loop_cycle
#     async for event in stream_messages(agent.model, agent.system_prompt, agent.messages, tool_specs):
#     ...<6 lines>...
#             }
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 319, in stream_messages
#     async for event in process_stream(chunks):
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 276, in process_stream
#     async for chunk in chunks:
#     ...<15 lines>...
#             handle_redact_content(chunk["redactContent"], state)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 397, in stream
#     await task
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py", line 171, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 494, in _stream
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 431, in _stream
#     response = self.client.converse_stream(**request)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# └ Bedrock region: ap-southeast-2
# └ Model id: us.anthropic.claude-sonnet-4-20250514-v1:0
# node=<market_analyst> | node execution failed
# Traceback (most recent call last):
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\multiagent\swarm.py", line 528, in _execute_swarm
#     await asyncio.wait_for(
#     ...<2 lines>...
#     )
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\asyncio\tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\multiagent\swarm.py", line 590, in _execute_node
#     result = await node.executor.invoke_async(node_input)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 435, in invoke_async
#     async for event in events:
#         _ = event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 577, in stream_async
#     async for event in events:
#     ...<2 lines>...
#             yield event["callback"]
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 614, in _run_loop
#     async for event in events:
#     ...<13 lines>...
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 653, in _execute_event_loop_cycle
#     async for event in events:
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 194, in event_loop_cycle
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 136, in event_loop_cycle
#     async for event in stream_messages(agent.model, agent.system_prompt, agent.messages, tool_specs):
#     ...<6 lines>...
#             }
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 319, in stream_messages
#     async for event in process_stream(chunks):
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 276, in process_stream
#     async for chunk in chunks:
#     ...<15 lines>...
#             handle_redact_content(chunk["redactContent"], state)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 397, in stream
#     await task
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py", line 171, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 494, in _stream
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 431, in _stream
#     response = self.client.converse_stream(**request)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# └ Bedrock region: ap-southeast-2
# └ Model id: us.anthropic.claude-sonnet-4-20250514-v1:0
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# I apologize for the continued errors. Let's simplify the request and try once more:
# Tool #3: swarm
# node=<market_analyst> | node execution failed
# Traceback (most recent call last):
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\multiagent\swarm.py", line 590, in _execute_node
#     result = await node.executor.invoke_async(node_input)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 435, in invoke_async
#     async for event in events:
#         _ = event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 577, in stream_async
#     async for event in events:
#     ...<2 lines>...
#             yield event["callback"]
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 614, in _run_loop
#     async for event in events:
#     ...<13 lines>...
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 653, in _execute_event_loop_cycle
#     async for event in events:
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 194, in event_loop_cycle
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 136, in event_loop_cycle
#     async for event in stream_messages(agent.model, agent.system_prompt, agent.messages, tool_specs):
#     ...<6 lines>...
#             }
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 319, in stream_messages
#     async for event in process_stream(chunks):
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 276, in process_stream
#     async for chunk in chunks:
#     ...<15 lines>...
#             handle_redact_content(chunk["redactContent"], state)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 397, in stream
#     await task
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py", line 171, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 494, in _stream
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 431, in _stream
#     response = self.client.converse_stream(**request)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# └ Bedrock region: ap-southeast-2
# └ Model id: us.anthropic.claude-sonnet-4-20250514-v1:0
# node=<market_analyst> | node execution failed
# Traceback (most recent call last):
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\multiagent\swarm.py", line 528, in _execute_swarm
#     await asyncio.wait_for(
#     ...<2 lines>...
#     )
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\asyncio\tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\multiagent\swarm.py", line 590, in _execute_node
#     result = await node.executor.invoke_async(node_input)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 435, in invoke_async
#     async for event in events:
#         _ = event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 577, in stream_async
#     async for event in events:
#     ...<2 lines>...
#             yield event["callback"]
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 614, in _run_loop
#     async for event in events:
#     ...<13 lines>...
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\agent\agent.py", line 653, in _execute_event_loop_cycle
#     async for event in events:
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 194, in event_loop_cycle
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\event_loop.py", line 136, in event_loop_cycle
#     async for event in stream_messages(agent.model, agent.system_prompt, agent.messages, tool_specs):
#     ...<6 lines>...
#             }
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 319, in stream_messages
#     async for event in process_stream(chunks):
#         yield event
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\event_loop\streaming.py", line 276, in process_stream
#     async for chunk in chunks:
#     ...<15 lines>...
#             handle_redact_content(chunk["redactContent"], state)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 397, in stream
#     await task
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py", line 171, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 494, in _stream
#     raise e
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\strands\models\bedrock.py", line 431, in _stream
#     response = self.client.converse_stream(**request)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "e:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv\Lib\site-packages\botocore\client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ValidationException: An error occurred (ValidationException) when calling the ConverseStream operation: The provided model identifier is invalid.
# └ Bedrock region: ap-southeast-2
# └ Model id: us.anthropic.claude-sonnet-4-20250514-v1:0
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# I apologize for the continued issues with the swarm function. It appears there may be technical limitations preventing the swarm from executing properly at the moment.
#
# Since the swarm approach isn't working, I'd be happy to provide you with a comprehensive analysis of the current market trends for generative AI-based agents myself. I can cover:
#
# 1. Market size and growth projections
# 2. Key players in the industry
# 3. Emerging applications and use cases
# 4. Technological developments
# 5. Challenges and limitations
# 6. Future outlook
#
# Would you like me to proceed with this analysis? Or would you prefer to try a different approach with the swarm functionality?

# %%
print(result)
# Out:
# I apologize for the continued issues with the swarm function. It appears there may be technical limitations preventing the swarm from executing properly at the moment.
#
# Since the swarm approach isn't working, I'd be happy to provide you with a comprehensive analysis of the current market trends for generative AI-based agents myself. I can cover:
#
# 1. Market size and growth projections
# 2. Key players in the industry
# 3. Emerging applications and use cases
# 4. Technological developments
# 5. Challenges and limitations
# 6. Future outlook
#
# Would you like me to proceed with this analysis? Or would you prefer to try a different approach with the swarm functionality?

# %% [markdown]
# The swarm tool implements a flexible swarm intelligence system built on the Strands SDK's native Swarm multi-agent pattern. This system enables users to define custom teams of specialized AI agents that collaborate autonomously through shared context and tool-based coordination.
#
# **Key Features:**
# - **Custom Agent Teams**: User-defined agent specifications with individual system prompts, per-agent tool configuration, and model settings
# - **Autonomous Coordination**: Built-in coordination tools (handoff_to_agent, complete_swarm_task) with shared working memory across all agents
# - **Advanced Configuration**: Individual model providers and settings per agent, customizable tool access, comprehensive timeout and safety mechanisms
# - **Emergent Collective Intelligence**: Agents autonomously decide when to collaborate or handoff, with dynamic task distribution based on capabilities
#
# The full implementation of the swarm tool can be found in the [Strands Tools repository](https://github.com/strands-agents/tools/blob/main/src/strands_tools/swarm.py).
#
# **Key Parameters:**
# - `task`: The main task to be processed by the swarm
# - `agents`: List of agent specifications with name, system_prompt, tools, model_provider, and model_settings
# - `max_handoffs`: Maximum number of agent handoffs allowed (default: 20)
# - `max_iterations`: Maximum total iterations across all agents (default: 20)
# - `execution_timeout`: Total execution timeout in seconds (default: 900.0)
# - `node_timeout`: Individual agent timeout in seconds (default: 300.0)
# - `repetitive_handoff_detection_window`: Number of recent nodes to check for ping-pong behavior
# - `repetitive_handoff_min_unique_agents`: Minimum unique nodes required in recent sequence
#
# **How the Swarm Tool Works:**
# 1. **Agent Creation**: Creates specialized agents based on user specifications with individual model providers and tools
# 2. **Swarm Initialization**: Sets up the Strands SDK Swarm with coordination tools and safety mechanisms
# 3. **Autonomous Execution**: Agents collaborate through handoffs and shared context without central control
# 4. **Result Aggregation**: Collects individual contributions and provides comprehensive execution metrics

# %% [markdown]
# ## 2. Creating a Swarm with Strands Agents

# %% [markdown]
# Strands Agents SDK allows you to create swarms using existing Agent objects, even when they use different model providers or have different configurations. The Swarm system enables autonomous coordination between agents through auto handoff mechanisms and shared context, allowing agents to dynamically transfer control when they need specialized expertise from other agents.
#
# ### 2.1 Agent Coordination with Auto Handoff

# %% [markdown]
# <p align="center">
#     <img src="./images/swarm_example.png">
# </p>

# %% [markdown]
# In this coordination approach, agents use the Strands SDK's native Swarm pattern with built-in handoff tools to autonomously transfer control to other specialized agents when they need different expertise. Each agent is automatically equipped with coordination tools like `handoff_to_agent` and `complete_swarm_task`. The following example demonstrates a swarm of specialized agents collaborating through shared context and autonomous handoffs:

# %%
# Create specialized agents with different expertise
research_agent = Agent(system_prompt=("""You are a Research Agent specializing in gathering and analyzing information.
Your role in the swarm is to provide factual information and research insights on the topic.
You should focus on providing accurate data and identifying key aspects of the problem.
When receiving input from other agents, evaluate if their information aligns with your research.
"""), 
name="research_agent",model="apac.anthropic.claude-3-7-sonnet-20250219-v1:0")

creative_agent = Agent(system_prompt=("""You are a Creative Agent specializing in generating innovative solutions.
Your role in the swarm is to think outside the box and propose creative approaches.
You should build upon information from other agents while adding your unique creative perspective.
Focus on novel approaches that others might not have considered.
"""), 
name="creative_agent",model="apac.anthropic.claude-3-7-sonnet-20250219-v1:0")

critical_agent = Agent(system_prompt=("""You are a Critical Agent specializing in analyzing proposals and finding flaws.
Your role in the swarm is to evaluate solutions proposed by other agents and identify potential issues.
You should carefully examine proposed solutions, find weaknesses or oversights, and suggest improvements.
Be constructive in your criticism while ensuring the final solution is robust.
"""), 
name="critical_agent",model="apac.anthropic.claude-3-7-sonnet-20250219-v1:0")

summarizer_agent = Agent(system_prompt=("""You are a Summarizer Agent specializing in synthesizing information.
Your role in the swarm is to gather insights from all agents and create a cohesive final solution.
You should combine the best ideas and address the criticisms to create a comprehensive response.
Focus on creating a clear, actionable summary that addresses the original query effectively.
"""),name="summarizer_agent",model="apac.anthropic.claude-3-7-sonnet-20250219-v1:0")

# %% [markdown]
# The agent coordination is implemented using the Strands SDK's native Swarm class, which automatically provides coordination tools and manages shared context:

# %%
from strands.multiagent import Swarm

# Create a swarm with these agents
swarm = Swarm(
    [research_agent, creative_agent, critical_agent, summarizer_agent],
    max_handoffs=20,
    max_iterations=20,
    execution_timeout=900.0,  # 15 minutes
    node_timeout=300.0,       # 5 minutes per agent
    repetitive_handoff_detection_window=8,  # There must be >= 3 unique agents in the last 8 handoffs
    repetitive_handoff_min_unique_agents=3
)

# %% [markdown]
# The swarm operates through autonomous agent coordination, with agents deciding when to handoff based on their expertise and the task requirements:

# %%
# Execute the swarm on a task
result = swarm("Create a blog post explaining Agentic AI then create a summary for a social media post.")
# Out:
# I'll help research information on Agentic AI to support creating a blog post. Since this task would benefit from specialized writing abilities after gathering the research, I'll need to collaborate with other agents in the swarm.
#
# Let me first gather key research points about Agentic AI:
#
# - Agentic AI refers to AI systems that can act autonomously on behalf of users to accomplish tasks
# - These AI systems have greater agency and independence compared to traditional AI
# - Key characteristics include goal-oriented behavior, persistence, adaptability, and autonomous decision-making
# - Agentic AI can take actions such as using tools, accessing the internet, or controlling physical systems
# - Examples include AI personal assistants, autonomous research agents, and AI systems that can plan and execute multi-step tasks
# - There are important considerations around alignment, safety, and responsible deployment
# - The technology represents a shift from passive AI tools to more active AI collaborators
#
# Since your request involves creating a blog post explaining Agentic AI and then a social media summary, I should hand this off to the Creative Agent who specializes in content creation.
# Tool #1: handoff_to_agent
# I'll help craft an engaging blog post about Agentic AI using the research points provided, followed by a social media summary. This is right up my alley as the Creative Agent!
#
# # Blog Post: The Rise of Agentic AI: From Tools to Partners
#
# ## The Evolution Beyond Passive AI
#
# Remember when AI was just a fancy calculator or a voice that would tell you the weather when asked? Those days are rapidly fading into history as we enter the era of Agentic AI—systems that don't just respond, but act independently on our behalf.
#
# Agentic AI represents a fundamental shift in how we interact with artificial intelligence. Rather than merely being passive tools waiting for our commands, these systems become proactive partners in achieving our goals. They're the difference between a hammer sitting in your toolbox and a helpful assistant who notices you're trying to hang a picture and offers not just to hand you the hammer, but to suggest better spots for the nail.
#
# ## What Makes AI "Agentic"?
#
# At its core, Agentic AI embodies four key characteristics that separate it from traditional AI systems:
#
# 1. **Goal-Oriented Behavior**: These systems understand objectives and actively work toward achieving them, not just following rigid instructions.
#
# 2. **Persistence**: Unlike conventional AI that completes a single task and stops, Agentic AI persists until goals are accomplished, navigating obstacles along the way.
#
# 3. **Adaptability**: When faced with unexpected situations, these systems adjust their approach rather than failing or requiring human intervention.
#
# 4. **Autonomous Decision-Making**: Perhaps most importantly, Agentic AI can make decisions independently within its domain, evaluating options and choosing the best path forward.
#
# ## Agentic AI in Action
#
# Imagine waking up to find your AI assistant has already rescheduled your morning meetings because it detected a transit delay on your usual route. Or picture an AI research agent that doesn't just search for information but synthesizes findings, identifies gaps in knowledge, and initiates new inquiries—all while you sleep.
#
# These aren't science fiction scenarios. Today's Agentic AI systems can use a variety of tools, access the internet independently, and even control other systems to accomplish their missions. From personal assistants that manage your digital life to specialized agents that handle complex research or creative tasks, Agentic AI is already transforming how we work and live.
#
# ## The Promise and the Challenge
#
# As with any powerful technology, the rise of Agentic AI brings both opportunity and responsibility. Key considerations include:
#
# - **Alignment**: Ensuring these autonomous systems truly understand and pursue our intended goals, not just literal interpretations of our instructions.
#
# - **Safety**: Building robust safeguards to prevent unintended consequences when AI acts independently.
#
# - **Responsible Deployment**: Considering the ethical implications of delegating increasingly complex tasks to artificial agents.
#
# ## A New Partnership
#
# The shift from passive AI tools to active AI collaborators represents one of the most significant evolutions in computing since the internet. As these systems become more capable and integrated into our daily lives, we're moving toward a future where the line between human and artificial intelligence becomes less about opposition and more about collaboration.
#
# Agentic AI isn't about replacing human creativity, judgment, or decision-making—it's about amplifying our capabilities and freeing us to focus on the uniquely human aspects of our work and lives.
#
# The question is no longer whether AI can follow our commands, but how we'll adapt to having persistent, autonomous digital partners working alongside us, anticipating our needs, and helping shape our future.
#
# ---
#
# # Social Media Summary:
#
# 📱 **The Rise of Agentic AI: From Tools to Partners**
#
# Beyond passive AI that waits for commands, Agentic AI systems act autonomously on our behalf! These digital partners show goal-oriented behavior, persistence, adaptability, and make decisions independently.
#
# From rescheduling meetings based on traffic to conducting research while you sleep, these systems represent the evolution from AI as tools to AI as collaborators.
#
# The future isn't about AI vs humans—it's about what we can accomplish together when AI handles the routine while we focus on being uniquely human.
#
# #AgenticAI #FutureOfTech #AICollaboration

# %%
# Access the final result
print(f"Status: {result.status}")
# Out:
# Status: Status.COMPLETED

# %% [markdown]
# In this example:
#
# * The research_agent might start by gathering information about Agentic AI
# * Handoff to the creative_agent to develop engaging content and structure
# * The critical_agent reviews the content for accuracy and completeness
# * Finally, the summarizer_agent synthesizes all contributions into a cohesive blog post
# * Agents can handoff multiple times as needed, with the swarm automatically managing coordination

# %%
# See which agents were involved
for node in result.node_history:
    print(f"Agent: {node.node_id}")

# Get results from specific nodes
research_result = result.results["research_agent"].result
print(f"Research: {research_result}")

# Get performance metrics
print(f"Total iterations: {result.execution_count}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")
# Out:
# Agent: research_agent
# Agent: creative_agent
# Research:
# Total iterations: 2
# Execution time: 33463ms
# Token usage: {'inputTokens': 2792, 'outputTokens': 1406, 'totalTokens': 4198}

# %% [markdown]
# The swarm system automatically manages agent coordination, shared context, and handoff mechanisms. Agents can autonomously decide when to transfer control to other specialists, creating a seamless collaborative workflow with built-in safety features like timeout protection and repetitive handoff detection.

# %% [markdown]
# ## When to use Swarm:
#
# - For complex tasks requiring diverse expertise and specialized knowledge
# - When you need multiple perspectives and collaborative problem-solving
# - For tasks that benefit from autonomous agent coordination and collective intelligence
# - When handling multi-modal inputs like text and images together
# - For projects requiring dynamic task distribution based on agent capabilities
#
# ## Best Practices
#
# 1. **Create specialized agents**: Define clear roles for each agent in your Swarm
# 2. **Use descriptive agent names**: Names should reflect the agent's specialty
# 3. **Set appropriate timeouts**: Adjust based on task complexity and expected runtime
# 4. **Enable repetitive handoff detection**: Set appropriate values for `repetitive_handoff_detection_window` and `repetitive_handoff_min_unique_agents` to prevent ping-pong behavior
# 5. **Include diverse expertise**: Ensure your Swarm has agents with complementary skills
# 6. **Provide agent descriptions**: Add descriptions to your agents to help other agents understand their capabilities
# 7. **Leverage multi-modal inputs**: Use ContentBlocks for rich inputs including images
#
# ## Conclusion
#
# Multi-agent swarms solve complex problems through emergent collective intelligence. The Strands Agents SDK provides both a flexible swarm tool and native Swarm class for creating custom agent teams that collaborate autonomously. By distributing tasks across specialized agents with individual model providers, tools, and configurations, swarms achieve better results than single agents working alone. With built-in coordination tools, shared context, and comprehensive safety mechanisms, developers can create sophisticated multi-agent systems that handle complex, multi-faceted problems through self-organizing collaboration.
#
# For further details on Swarms check out the [Strands Documentation](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/multi-agent/swarm/)

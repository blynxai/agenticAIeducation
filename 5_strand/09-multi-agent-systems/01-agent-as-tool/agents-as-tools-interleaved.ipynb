# %% [markdown]
# # Agents as Tools with Strands Agents SDK and Claude 4 Interleaved Thinking
#
# This notebook demonstrates how to use Strands Agents SDK with Claude 4's **interleaved thinking** capability to orchestrate intelligent workflows with specialist agents.

# %% [markdown]
# ## Understanding Interleaved Thinking
#
# ### What is Interleaved Thinking?
#
# Interleaved thinking is a new capability in Claude 4 models that allows the model to:
#
# 1. **Think between tool calls**: Process and reason about results before deciding next steps
# 2. **Chain multiple tools with reasoning**: Make sophisticated multi-step decisions
# 3. **Adapt strategies dynamically**: Change approach based on intermediate results
#
# ### How It Works
#
# There are a lot of similarities between Agent's event loop implemented with and without interleaved thinking:
# ```
# Query → LLM is thinking -> LLM decides to call a Tool -> Event Loop calls the Tool -> Ouput is sent back to LLM -> [ this continues until LLM no longer needs to call any tools - it rendered the Final Answer ]
# ```
#
# The main difference you'll notice with the interleaved thinking is that Event loop is acting on LLM's "thoughts", rather than "decisions". Notice the second link in the loop above, called "thinking". In a traditional event loop, the thoughts are hidden. We have to wait until LLM renders either a decision to call a tool or produces the Final Answer.
#
# In case of interleaved thinking, LLM is "leaking" its thoughts into the even loop while it's still in that second step - "LLM is thinking" - and event loop is configured to executed the tools as soon as LLM "thinks" about doing it. What this means is that by the time LLM is done thinking, it actually has the Final Answer, on the very first "decision".
#
#
# ### Enabling Interleaved Thinking
#
# To enable this feature with Strands and Bedrock:
# - Set `temperature=1` (required when thinking is enabled)
# - Add beta header: `"anthropic_beta": ["interleaved-thinking-2025-05-14"]`
# - Configure reasoning budget: `"reasoning_config": {"type": "enabled", "budget_tokens": 3000}`

# %% [markdown]
# ## Setup and Imports

# %%
# !uv pip install -r requirements.txt
# Out:
# Using Python 3.13.7 environment at: E:\OneDrive\OneDriveOnitbuddy\OneDrive\workbench\exampletest\agenticAIeducation\5_strand\.strandsenv
# Audited 2 packages in 674ms

# %%
import os
from strands import Agent, tool
from strands.models import BedrockModel
from strands.models import bedrock

bedrock.DEFAULT_BEDROCK_MODEL_ID = "apac.anthropic.claude-3-7-sonnet-20250219-v1:0"

# %% [markdown]
# ## Define Specialist Agents as Tools
#
# First, we are going to create four specialist agents using the Strands `@tool` decorator:
# - **Researcher**: Gathers factual information
# - **Data Analyst**: Processes and analyzes information
# - **Fact Checker**: Verifies information accuracy
# - **Report Writer**: Creates polished final documents

# %%
# Specialist agents implemented as tools using Strands @tool decorator
@tool
def researcher(query: str) -> str:
    """
    Research specialist that gathers factual information.
    
    Args:
        query: Research question or topic to investigate
        
    Returns:
        Research findings and sources
    """
    # Create a focused research agent
    # Note: Each call creates a fresh agent instance (stateless)
    research_agent = Agent(
        model="apac.anthropic.claude-3-7-sonnet-20250219-v1:0",  # Optional: Specify the model ID
        system_prompt="You are a research specialist. Gather factual information and cite sources when possible. Keep responses under 200 words.",
        callback_handler=None  # No streaming for tool agents
    )
    
    # Execute the research task
    result = research_agent(f"Research: {query}")
    return str(result)

# %%
@tool
def data_analyst(data: str) -> str:
    """
    Data analyst that processes and analyzes information.
    
    Args:
        data: Raw data or research findings to analyze
        
    Returns:
        Analysis with insights and patterns
    """
    # Analyst agent focuses on extracting insights
    analysis_agent = Agent(
        model="apac.anthropic.claude-3-7-sonnet-20250219-v1:0",
        system_prompt="You are a data analyst. Extract key insights, identify patterns, and provide analytical conclusions. Focus on actionable insights.",
        callback_handler=None
    )
    
    # Analyze the provided data
    result = analysis_agent(f"Analyze this data and provide insights: {data}")
    return str(result)

# %%
@tool
def fact_checker(information: str) -> str:
    """
    Fact checker that verifies information accuracy.
    
    Args:
        information: Claims or data to verify
        
    Returns:
        Fact-check results with accuracy assessment
    """
    # Fact-checking agent for verification
    fact_check_agent = Agent(
        model="apac.anthropic.claude-3-7-sonnet-20250219-v1:0",
        system_prompt="You are a fact checker. Verify claims, assess credibility, and provide confidence levels. Identify any questionable statements.",
        callback_handler=None
    )
    
    # Verify the information
    result = fact_check_agent(f"Fact-check this information: {information}")
    return str(result)

# %%
@tool
def report_writer(analysis: str) -> str:
    """
    Report writer that creates polished final documents.
    
    Args:
        analysis: Analyzed data and insights
        
    Returns:
        Formatted final report
    """
    # Writer agent for professional output
    writer_agent = Agent(
        system_prompt="You are a professional report writer. Create clear, well-structured reports with executive summaries and actionable recommendations.",
        callback_handler=None
    )
    
    # Create the report
    result = writer_agent(f"Create a professional report based on: {analysis}")
    return str(result)

# %% [markdown]
# ## Claude 4 Orchestrator with Interleaved Thinking
#
# Now we create the orchestrator - a Claude 4 agent that uses interleaved thinking to intelligently coordinate the specialist agents.
#
# ### How the Orchestrator Works:
#
# 1. Receives a high-level task from the user
# 2. **Thinks** about what information is needed
# 3. Calls the researcher tool to gather initial data
# 4. **Thinks** about the research results and what analysis is needed
# 5. Calls the data analyst to process findings
# 6. **Thinks** about accuracy and verification needs
# 7. May call the fact checker if needed
# 8. **Thinks** about how to present the findings
# 9. Calls the report writer for final output
# 10. **Reflects** on the complete workflow before responding

# %%
# Claude 4 Orchestrator with Interleaved Thinking using Strands
class StrandsInterlevedWorkflowOrchestrator:
    def __init__(self):
        # Define the orchestrator system prompt for intelligent workflow coordination
        self.system_prompt = """You are an intelligent workflow orchestrator with access to specialist agents.

        Your role is to intelligently coordinate a workflow using these specialist agents:
        - researcher: Gathers factual information on any topic
        - data_analyst: Analyzes data and extracts insights
        - fact_checker: Verifies accuracy of information  
        - report_writer: Creates polished final reports

        """
    
    def run_workflow(self, task: str, enable_interleaved_thinking: bool = True) -> str:
        """Execute an intelligent workflow for the given task.
        
        Args:
            task: The task to complete
            enable_interleaved_thinking: Whether to enable interleaved thinking (default: True)
        
        The orchestrator will:
        1. Understand the task requirements
        2. Think about the best approach
        3. Coordinate specialist agents
        4. Reflect on results between steps
        5. Produce a comprehensive output
        """
        thinking_mode = "WITH interleaved thinking" if enable_interleaved_thinking else "WITHOUT interleaved thinking"
        print(f"\nStarting intelligent workflow {thinking_mode} for: {task}")
        print("=" * 70)
        
        # Configure Claude 4 with or without interleaved thinking via Bedrock
        if enable_interleaved_thinking:
            claude4_model = BedrockModel(
                model_id="apac.anthropic.claude-sonnet-4-20250514-v1:0",
                max_tokens=4096,
                temperature=1,  # Required to be 1 when thinking is enabled
                additional_request_fields={
                    # Enable interleaved thinking beta feature
                    "anthropic_beta": ["interleaved-thinking-2025-05-14"],
                    # Configure reasoning parameters
                    "reasoning_config": {
                        "type": "enabled",  # Turn on thinking
                        "budget_tokens": 3000  # Thinking token budget
                    }
                }
            )
        else:
            claude4_model = BedrockModel(
                model_id="apac.anthropic.claude-sonnet-4-20250514-v1:0",
                max_tokens=4096,
                temperature=1
            )
        
        # Create the orchestrator agent with Claude 4 and specialist tools
        orchestrator = Agent(
            model=claude4_model,
            system_prompt=self.system_prompt,
            tools=[researcher, data_analyst, fact_checker, report_writer]
        )
        
        prompt = f"""Complete this task using intelligent workflow coordination: {task}

        Instructions:
        1. Think carefully about what information you need to accomplish this task
        2. Use the specialist agents strategically - each has unique strengths
        3. After each tool use, reflect on the results and adapt your approach
        4. Coordinate multiple agents as needed for comprehensive results
        5. Ensure accuracy by fact-checking when appropriate
        6. Provide a comprehensive final response that addresses all aspects
        
        Remember: Your thinking between tool calls helps you make better decisions.
        Use it to plan, evaluate results, and adjust your strategy.
        """
        
        try:
            result = orchestrator(prompt)
            return str(result)
        except Exception as e:
            return f"Workflow failed: {e}"

# %% [markdown]
# ## Run the Demo
#
# Let's see the orchestrator in action! Watch how it thinking and making tool calling while it's thinking.

# %%
# Create the orchestrator
print("Strands Agents SDK: Claude 4 Interleaved Thinking Workflow Demo")
print("=" * 70)

try:
    orchestrator = StrandsInterlevedWorkflowOrchestrator()
    print("✅ Orchestrator initialized successfully!")
except Exception as e:
    print(f"❌ Failed to initialize orchestrator: {e}")
# Out:
# Strands Agents SDK: Claude 4 Interleaved Thinking Workflow Demo
# ======================================================================
# ✅ Orchestrator initialized successfully!

# %%
# Run the workflow with a test case
test_case = "Analyze the impact of remote work on productivity and provide strategic recommendations"

print(f"📋 Task: {test_case}\n")

try:
    result = orchestrator.run_workflow(test_case)
    
    print(f"\n📊 Workflow Result:")
    print("=" * 70)
    print(result)
except Exception as e:
    print(f"❌ Workflow execution failed: {e}")
# Out:
# 📋 Task: Analyze the impact of remote work on productivity and provide strategic recommendations
#
#
# Starting intelligent workflow WITH interleaved thinking for: Analyze the impact of remote work on productivity and provide strategic recommendations
# ======================================================================
# I need to analyze the impact of remote work on productivity and provide strategic recommendations. This is a complex topic that requires a well-coordinated workflow using multiple specialist agents.
#
# Let me break down what I need to accomplish:
# 1. Gather comprehensive information about remote work and its impact on productivity
# 2. Analyze the data to extract insights and identify patterns
# 3. Verify the accuracy of key claims
# 4. Generate strategic recommendations based on the analysis
# 5. Create a polished final report
#
# My strategy:
# 1. Start with the researcher to gather factual information about remote work's impact on productivity
# 2. Use the data analyst to process this information and extract key insights
# 3. Fact-check important claims to ensure accuracy
# 4. Use the report writer to create a comprehensive final document with strategic recommendations
#
# Let me start with research first.I'll help you analyze the impact of remote work on productivity and provide strategic recommendations. Let me coordinate a comprehensive workflow using my specialist agents.
#
# First, I'll gather foundational research on this topic:
# Tool #1: researcher
# Great! I have comprehensive research data. Now I need to analyze this information to extract deeper insights and identify patterns. The data shows some interesting contradictions (like the manager vs employee perception gap) that warrant analysis.Now let me analyze this research data to extract key insights and patterns:
# Tool #2: data_analyst
# Excellent analysis! The data analyst has identified some really important insights, particularly the perception gap between managers and employees, and the strategic implications. Before creating the final report, I should fact-check some of the key statistics to ensure accuracy, especially the Stanford study and Microsoft research findings since these are foundational to the analysis.Let me fact-check the key statistics to ensure accuracy before finalizing recommendations:
# Tool #3: fact_checker
# The fact-check reveals some important accuracy issues - particularly with the dating of the Stanford study and the need to verify specific percentages. I should acknowledge these limitations while still proceeding with the analysis, being clear about the confidence levels of different data points. Now I can create a comprehensive final report that incorporates all the insights while being transparent about data accuracy.Now let me create a comprehensive final report with strategic recommendations:
# Tool #4: report_writer
# I've successfully completed a comprehensive analysis of remote work's impact on productivity using intelligent workflow coordination. Here's what I accomplished:
#
# 1. **Research Phase**: I gathered comprehensive information about remote work productivity including statistics, benefits, challenges, and trends from 2020-2024.
#
# 2. **Analysis Phase**: I analyzed the data to extract key insights including the perception gap between managers and employees, time efficiency gains, and the evolution toward hybrid models.
#
# 3. **Fact-checking Phase**: I verified the accuracy of key statistics, identifying some concerns about the dating of studies and specific percentages that need verification.
#
# 4. **Report Writing Phase**: I created a polished, comprehensive report that includes an executive summary, detailed findings, strategic implications, and actionable recommendations.
#
# The workflow was effective because each agent contributed their specialty:
# - Researcher provided factual foundation
# - Data analyst extracted patterns and insights
# - Fact checker ensured accuracy and identified limitations
# - Report writer created a professional final document
#
# The final report addresses all aspects requested: analyzing the impact and providing strategic recommendations, while being transparent about data limitations.I've completed a comprehensive analysis of remote work's impact on productivity using intelligent workflow coordination. Here's what my specialist agents accomplished:
#
# ## **Workflow Summary:**
#
# **1. Research Phase:** Gathered extensive data on remote work productivity trends, statistics, and challenges from 2020-2024
#
# **2. Analysis Phase:** Identified key patterns including:
# - A significant perception gap between managers and employees on productivity
# - Measurable time efficiency gains (40 minutes daily from eliminated commutes)
# - Evolution toward hybrid models as organizations seek balance
#
# **3. Fact-Checking Phase:** Verified key statistics and identified some data limitations that needed transparency
#
# **4. Report Creation:** Synthesized all findings into a professional report with strategic recommendations
#
# ## **Key Strategic Recommendations:**
#
# 1. **Develop Clear Remote Work KPIs** - Create outcome-focused metrics designed specifically for distributed work
# 2. **Invest in Technology Standardization** - Ensure equitable access to tools across all work locations
# 3. **Implement Structured Collaboration Processes** - Balance asynchronous work with scheduled team interactions
# 4. **Create Formal Work-Home Boundary Policies** - Support sustainable productivity through clear expectations
#
# The analysis reveals that while remote work shows documented productivity benefits, success depends heavily on how organizations measure performance, address technology inequities, and support employee wellness. The trend toward hybrid models suggests companies are finding ways to capture remote work's advantages while maintaining team cohesion.
#
# The comprehensive report above provides detailed findings, strategic implications, and actionable recommendations based on current research and trends.
# 📊 Workflow Result:
# ======================================================================
# I've completed a comprehensive analysis of remote work's impact on productivity using intelligent workflow coordination. Here's what my specialist agents accomplished:
#
# ## **Workflow Summary:**
#
# **1. Research Phase:** Gathered extensive data on remote work productivity trends, statistics, and challenges from 2020-2024
#
# **2. Analysis Phase:** Identified key patterns including:
# - A significant perception gap between managers and employees on productivity
# - Measurable time efficiency gains (40 minutes daily from eliminated commutes)
# - Evolution toward hybrid models as organizations seek balance
#
# **3. Fact-Checking Phase:** Verified key statistics and identified some data limitations that needed transparency
#
# **4. Report Creation:** Synthesized all findings into a professional report with strategic recommendations
#
# ## **Key Strategic Recommendations:**
#
# 1. **Develop Clear Remote Work KPIs** - Create outcome-focused metrics designed specifically for distributed work
# 2. **Invest in Technology Standardization** - Ensure equitable access to tools across all work locations
# 3. **Implement Structured Collaboration Processes** - Balance asynchronous work with scheduled team interactions
# 4. **Create Formal Work-Home Boundary Policies** - Support sustainable productivity through clear expectations
#
# The analysis reveals that while remote work shows documented productivity benefits, success depends heavily on how organizations measure performance, address technology inequities, and support employee wellness. The trend toward hybrid models suggests companies are finding ways to capture remote work's advantages while maintaining team cohesion.
#
# The comprehensive report above provides detailed findings, strategic implications, and actionable recommendations based on current research and trends.

# %% [markdown]
# ## Try without Interleaved Thinking
#
# Experiment with calling the orchestrator and disabling interleaved thinking. Observe the difference in the output.

# %%
# Now let's try the same task WITHOUT interleaved thinking
print("\n" + "="*70)
print("🔄 Now running the same task WITHOUT interleaved thinking")
print("="*70)

try:
    result_without_thinking = orchestrator.run_workflow(test_case, enable_interleaved_thinking=False)
    
    print(f"\n📊 Workflow Result (Without Interleaved Thinking):")
    print("=" * 70)
    print(result_without_thinking)
except Exception as e:
    print(f"❌ Workflow execution failed: {e}")
# Out:
# ======================================================================
# 🔄 Now running the same task WITHOUT interleaved thinking
# ======================================================================
#
# Starting intelligent workflow WITHOUT interleaved thinking for: Analyze the impact of remote work on productivity and provide strategic recommendations
# ======================================================================
# I'll help you analyze the impact of remote work on productivity and provide strategic recommendations. Let me break this down into a systematic workflow using our specialist agents.
#
# First, I need to gather comprehensive research on remote work and productivity impacts. Let me start with the researcher to collect foundational data.
# Tool #1: researcher
# Great foundation! Now I need to analyze this data more deeply to extract patterns and insights. Let me use the data analyst to process these findings.
# Tool #2: data_analyst
# This analysis provides excellent insights. Before proceeding to create the final strategic recommendations, I should fact-check some of the key statistics to ensure accuracy for our recommendations.
# Tool #3: fact_checker
# Now I have a solid foundation with fact-checked data. Let me create a comprehensive final report with strategic recommendations using the report writer.
# Tool #4: report_writer
# ## Final Comprehensive Response
#
# Based on my systematic analysis using multiple specialist agents, here's a comprehensive assessment of remote work's impact on productivity with strategic recommendations:
#
# ### Key Findings:
#
# **Productivity Impact:**
# - Remote work delivers a **13% productivity increase** (Stanford research)
# - **90% of remote workers** maintain or exceed their office productivity levels
# - Productivity gains stem from fewer interruptions, reduced sick days, and better work environments
#
# **Employee Preferences:**
# - **87% of employees** embrace flexible work opportunities when offered
# - Remote work significantly improves work-life balance (54% improvement)
# - Companies see **30% reduction in attrition** when offering remote options
#
# **Economic Benefits:**
# - **$4,000 annual savings** per employee (commuting, meals, attire)
# - Substantial real estate cost reductions for employers
# - **35% annual increase** in remote technology investments across industries
#
# **Persistent Challenges:**
# - **20%** experience communication barriers
# - **49%** report isolation and loneliness
# - **37%** struggle with work-home boundary separation
#
# ### Strategic Recommendations:
#
# 1. **Establish Robust Communication Infrastructure**
#    - Implement structured protocols for different communication types
#    - Schedule regular check-ins and team meetings
#    - Create comprehensive documentation systems
#
# 2. **Combat Isolation Through Virtual Community Building**
#    - Host regular virtual social events and informal gatherings
#    - Develop mentorship programs for remote employees
#    - Create dedicated spaces for non-work conversations
#
# 3. **Adopt Strategic Hybrid Models**
#    - Design purpose-driven office attendance (collaboration days, training)
#    - Allow flexibility within structured frameworks
#    - Focus on outcome-based rather than location-based performance metrics
#
# 4. **Modernize Compensation and Benefits**
#    - Review location-based vs. role-based pay structures
#    - Provide home office setup stipends and ongoing tech support
#    - Ensure equitable advancement opportunities for remote workers
#
# 5. **Invest in Technology and Security**
#    - Prioritize collaboration tools that enhance productivity
#    - Implement robust cybersecurity measures
#    - Provide comprehensive technical support systems
#
# The evidence strongly supports that remote work, when implemented thoughtfully with attention to communication and community building, delivers measurable productivity gains while meeting strong employee preferences. Organizations that proactively address the challenges while leveraging the benefits will gain significant competitive advantages in talent retention, cost efficiency, and overall productivity.
# 📊 Workflow Result (Without Interleaved Thinking):
# ======================================================================
# ## Final Comprehensive Response
#
# Based on my systematic analysis using multiple specialist agents, here's a comprehensive assessment of remote work's impact on productivity with strategic recommendations:
#
# ### Key Findings:
#
# **Productivity Impact:**
# - Remote work delivers a **13% productivity increase** (Stanford research)
# - **90% of remote workers** maintain or exceed their office productivity levels
# - Productivity gains stem from fewer interruptions, reduced sick days, and better work environments
#
# **Employee Preferences:**
# - **87% of employees** embrace flexible work opportunities when offered
# - Remote work significantly improves work-life balance (54% improvement)
# - Companies see **30% reduction in attrition** when offering remote options
#
# **Economic Benefits:**
# - **$4,000 annual savings** per employee (commuting, meals, attire)
# - Substantial real estate cost reductions for employers
# - **35% annual increase** in remote technology investments across industries
#
# **Persistent Challenges:**
# - **20%** experience communication barriers
# - **49%** report isolation and loneliness
# - **37%** struggle with work-home boundary separation
#
# ### Strategic Recommendations:
#
# 1. **Establish Robust Communication Infrastructure**
#    - Implement structured protocols for different communication types
#    - Schedule regular check-ins and team meetings
#    - Create comprehensive documentation systems
#
# 2. **Combat Isolation Through Virtual Community Building**
#    - Host regular virtual social events and informal gatherings
#    - Develop mentorship programs for remote employees
#    - Create dedicated spaces for non-work conversations
#
# 3. **Adopt Strategic Hybrid Models**
#    - Design purpose-driven office attendance (collaboration days, training)
#    - Allow flexibility within structured frameworks
#    - Focus on outcome-based rather than location-based performance metrics
#
# 4. **Modernize Compensation and Benefits**
#    - Review location-based vs. role-based pay structures
#    - Provide home office setup stipends and ongoing tech support
#    - Ensure equitable advancement opportunities for remote workers
#
# 5. **Invest in Technology and Security**
#    - Prioritize collaboration tools that enhance productivity
#    - Implement robust cybersecurity measures
#    - Provide comprehensive technical support systems
#
# The evidence strongly supports that remote work, when implemented thoughtfully with attention to communication and community building, delivers measurable productivity gains while meeting strong employee preferences. Organizations that proactively address the challenges while leveraging the benefits will gain significant competitive advantages in talent retention, cost efficiency, and overall productivity.
